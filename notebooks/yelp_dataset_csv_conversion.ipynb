# %% [markdown]
# # Converting Yelp Dataset json files to CSV
#
# Medium Article - [Convert Yelp Dataset to CSV using Pandas](https://link.medium.com/0k0DEb3Qy1)
#
# [GitHub Repo](https://github.com/gyhou/yelp_dataset)

# %% [markdown]
# ## Data Source
# https://www.yelp.com/dataset/
# - Unzip the first .tar file, it will extract a single file
# - Add .tar to the end of the file's name to unzip it again
# - The second file will extract 6 json files

# %%
# Need to upgrade pandas to version 0.25 to use "explode" function
# !py -m venv venv
# !venv\Scripts\activate
# !pip install pandas

# %%
import pandas as pd
pd.__version__
# Out:
# '2.3.3'

# %% [markdown]
# ## To match the review texts with business info, we need to merge the two json files

# %% [markdown]
# ### Load and Clean Business.json file

# %%
# Set up your local path
business_json_path = 'business.json'
business = pd.read_json(business_json_path, lines=True)
print(business.shape)
business.head()
# Out:
# (150346, 14)
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1  87 Grasso Plaza Shopping Center         Affton    MO       63123
# 2             5255 E Broadway Blvd         Tucson    AZ       85711
# 3                      935 Race St   Philadelphia    PA       19107
# 4                    101 Walnut St     Green Lane    PA       18054
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  34.426679 -119.711197    5.0             7        0
# 1  38.551126  -90.335695    3.0            15        1
# 2  32.223236 -110.880452    3.5            22        0
# 3  39.955505  -75.155564    4.0            80        1
# 4  40.338183  -75.471659    4.5            13        1
#
#                                           attributes  \
# 0                      {'ByAppointmentOnly': 'True'}
# 1             {'BusinessAcceptsCreditCards': 'True'}
# 2  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 3  {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 4  {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
#
#                                           categories  \
# 0  Doctors, Traditional Chinese Medicine, Naturop...
# 1  Shipping Centers, Local Services, Notaries, Ma...
# 2  Department Stores, Shopping, Fashion, Home & G...
# 3  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                          Brewpubs, Breweries, Food
#
#                                                hours
# 0                                               None
# 1  {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:30', ...
# 2  {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...
# 3  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 4  {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...

# %%
business.to_csv("yelp_business.csv", index=False) # Save as CSV file without the index column

# %%
# There are significant amount of businesses that are not open anymore
business.is_open.value_counts()
# Out:
# is_open
# 1    119698
# 0     30648
# Name: count, dtype: int64

# %%
# Keep only business that are still open
# Drop columns that may not be relavent
df_business = business[business['is_open']==1].drop(['hours','is_open','review_count'], axis=1)
print(df_business.shape)
df_business.head()
# Out:
# (119698, 11)
#               business_id                      name  \
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# 5  CF33F8-E6oudUQ46HnavjQ            Sonic Drive-In
# 6  n_0UpQx1hsNbnPUSlodU8w           Famous Footwear
#
#                                       address          city state postal_code  \
# 1             87 Grasso Plaza Shopping Center        Affton    MO       63123
# 3                                 935 Race St  Philadelphia    PA       19107
# 4                               101 Walnut St    Green Lane    PA       18054
# 5                               615 S Main St  Ashland City    TN       37015
# 6  8522 Eager Road, Dierbergs Brentwood Point     Brentwood    MO       63144
#
#     latitude  longitude  stars  \
# 1  38.551126 -90.335695    3.0
# 3  39.955505 -75.155564    4.0
# 4  40.338183 -75.471659    4.5
# 5  36.269593 -87.058943    2.0
# 6  38.627695 -90.340465    2.5
#
#                                           attributes  \
# 1             {'BusinessAcceptsCreditCards': 'True'}
# 3  {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 4  {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
# 5  {'BusinessParking': 'None', 'BusinessAcceptsCr...
# 6  {'BusinessAcceptsCreditCards': 'True', 'Restau...
#
#                                           categories
# 1  Shipping Centers, Local Services, Notaries, Ma...
# 3  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                          Brewpubs, Breweries, Food
# 5  Burgers, Fast Food, Sandwiches, Food, Ice Crea...
# 6  Sporting Goods, Fashion, Shoe Stores, Shopping...

# %% [markdown]
# ### Find relevant categories
#
# One way to split the reviews is by category

# %%
# df.explode requires pandas ver 0.25
# Create one row for each series that contain comma-separated items
df_explode = df_business.assign(categories = df_business.categories.str.split(', ')).explode('categories')
df_explode.sample(9)
# Out:
#                    business_id                                 name  \
# 87604   h2-mPUMYJ5pF_gVurDL3lw  Azian Restaurant Sushi & Korean BBQ
# 145602  USaA0VJQf5EoD7zsIZP1Ag           Hyundai of New Port Richey
# 74561   fYwa1dnZC8LiII2ArgDDoQ                   Richie's Hot Wings
# 3419    2K19T1WL1EqTPs4KYjrkeQ             AFC URGENT CARE SEMINOLE
# 99049   4xu5AxIquZThauX74w5hSA     Tullycross Fine Irish Handcrafts
# 140804  YLR0La5ptvM2b2F9KHS5-g                     Best-One of Indy
# 133182  7JfmABOQj-OKTsf0ay3-cg               Applebee's Grill + Bar
# 27127   KjwrNpjp0wkovwKydQ3tWw                           Sushi Stop
# 99507   B71qd7T1voSiewKHUWD1cg      Summit Acupuncture Philadelphia
#
#                        address             city state postal_code   latitude  \
# 87604        15 N Alvernon Way           Tucson    AZ       85711  32.222275
# 145602              3936 US 19  New Port Richey    FL       34652  28.216025
# 74561        2934 Highway 31 W      White House    TN       37188  36.462546
# 3419    11241 Park Blvd, Ste A         Seminole    FL       33772  27.841765
# 99049             110 South St     Philadelphia    PA       19147  39.940900
# 140804   11578 Allisonville Rd          Fishers    IN       46038  39.955175
# 133182   610 West Nicholson Rd          Audubon    NJ       08106  39.893008
# 27127      882 Jacksonville Rd          Ivyland    PA       18974  40.203297
# 99507    421 N 7th St, Ste 205     Philadelphia    PA       19123  39.958919
#
#          longitude  stars                                         attributes  \
# 87604  -110.909892    2.5  {'RestaurantsReservations': 'True', 'OutdoorSe...
# 145602  -82.737035    2.5  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 74561   -86.660690    4.0  {'NoiseLevel': 'u'quiet'', 'BikeParking': 'Tru...
# 3419    -82.794712    2.0  {'BusinessAcceptsCreditCards': 'True', 'Accept...
# 99049   -75.144437    5.0  {'RestaurantsPriceRange2': '2', 'BusinessAccep...
# 140804  -86.041217    4.0  {'WiFi': 'u'free'', 'BusinessAcceptsCreditCard...
# 133182  -75.087907    2.0  {'RestaurantsAttire': 'u'casual'', 'GoodForKid...
# 27127   -75.076035    4.5  {'BusinessAcceptsCreditCards': 'True', 'Alcoho...
# 99507   -75.150019    5.0  {'ByAppointmentOnly': 'True', 'AcceptsInsuranc...
#
#                           categories
# 87604                           Food
# 145602                    Automotive
# 74561                  Chicken Wings
# 3419                         Doctors
# 99049                  Arts & Crafts
# 140804                   Auto Repair
# 133182                          Bars
# 27127                          Ramen
# 99507   Traditional Chinese Medicine

# %%
print('Total number of categories:', len(df_explode.categories.value_counts()))
print('Top 10 categories:')
df_explode.categories.value_counts()[:10]
# Out:
# Total number of categories: 1302
# Top 10 categories:
# categories
# Restaurants                  34987
# Food                         20419
# Shopping                     20186
# Home Services                13322
# Beauty & Spas                12263
# Health & Medical             11046
# Local Services               10138
# Automotive                    9879
# Nightlife                     8379
# Event Planning & Services     8173
# Name: count, dtype: int64

# %%
# Finding categories that contains RV
df_explode[df_explode['categories'].str.contains('RV', case=True, na=False)].categories.value_counts()
# Out:
# categories
# RV Repair     103
# RV Dealers    103
# RV Parks       82
# RV Rental      54
# Name: count, dtype: int64

# %%
# Keep only business with categories that are RV related (including Campgrounds)
business_RV = df_business[df_business['categories'].str.contains(
                         'RV Repair|RV Dealers|RV Rental|RV Parks|Campgrounds', case=False, na=False)]
print(business_RV.shape)
business_RV.head()
# Out:
# (284, 11)
#                  business_id                      name  \
# 219   25Uww0C0wvF9CZ_3B6vWtA        Enjoy The Mountain
# 225   cSeA6pC9JUlGfz-RNfvnGw         Midwest RV Center
# 961   nazEG-Y2LF4nL4bIIz7DKg  Clearwater Travel Resort
# 1777  nfNOqJTJa-jAHxiyZSyY8g          Woody's RV World
# 2019  p7RzIdqbVGD-qaqPx2WRtw                  Fretz RV
#
#                              address           city state postal_code  \
# 219                      1 Garden St  Santa Barbara    CA       93105
# 225   6200 Heimos Industrial Park Dr      St. Louis    MO       63129
# 961            2946 Gulf To Bay Blvd     Clearwater    FL       33759
# 1777     14510 Mark Messier Trail NW       Edmonton    AB     T6V 1H5
# 2019             3479 Bethlehem Pike      Souderton    PA       18964
#
#        latitude   longitude  stars  \
# 219   34.414342 -119.687332    4.5
# 225   38.464156  -90.371669    4.0
# 961   27.962428  -82.714922    3.5
# 1777  53.607767 -113.586814    1.0
# 2019  40.318542  -75.303180    3.0
#
#                                              attributes  \
# 219   {'WheelchairAccessible': 'True', 'BikeParking'...
# 225   {'BikeParking': 'True', 'RestaurantsPriceRange...
# 961                                 {'WiFi': 'u'free''}
# 1777                                               None
# 2019  {'WiFi': 'u'free'', 'ByAppointmentOnly': 'True...
#
#                                              categories
# 219   Motorcycle Rental, Tours, Hiking, Mountain Bik...
# 225   Trailer Dealers, Auto Parts & Supplies, Auto R...
# 961              Hotels & Travel, RV Parks, Campgrounds
# 1777  Automotive, RV Repair, Trailer Dealers, RV Dea...
# 2019  RV Parks, Car Dealers, RV Dealers, RV Repair, ...

# %% [markdown]
# ### Loading Massive file as chunks in Pandas
#
# With a huge file like yelp dataset, loading all the data at once will most likely crash your computer.
#
# Luckily, pandas has an option to load large data by segmenting the file into smaller chunks.

# %%
# Set up your local path
review_json_path = 'review.json'

# %%
import pandas as pd

# Set chunk size (smaller if dataset is smaller)
# 2019 Yelp review.json has more than 6 million reviews(rows)
size = 100000
review = pd.read_json(review_json_path, lines=True,
                      # identifying the data type of each column can reduce memory usage
                      dtype={'review_id':str,'user_id':str,'business_id':str,'stars':int,
                             'date':str,'text':str,'useful':int,'funny':int,'cool':int},
                      chunksize=size)

# review = pd.read_json(review_json_path, lines=True, chunksize=size)

# # Contar número total de linhas processadas
# total = 0
# for chunk in review:
#     total += len(chunk)
#     print(f"Processado {total} linhas até agora...")

# print(f"Total de linhas: {total}")

# %%
# # To display dataframe in Jupyter Notebook if not auto displayed using print
# from IPython.display import display

# with open(review_json_path, 'r', encoding='utf-8') as f:
#     review = pd.read_json(f, lines=True, chunksize=size)
#     first_chunk = next(review)
#     print(first_chunk.shape)
#     display(first_chunk)

# %% [markdown]
# ### Merge Review.json and Business.json file
#
# By merging only the relevant businesses to the review file, the final dataset will only consist of reviews from those businesses

# %%
# There are multiple chunks to be read
chunk_list = []
for chunk in review:
    # Drop columns that aren't needed
    chunk = chunk.drop(['review_id','useful','funny','cool'], axis=1)
    # Renaming column name to avoid conflict with business overall star rating
    chunk = chunk.rename(columns={'stars': 'review_stars'})
    # Inner merge with edited business file so only reviews related to the business remain
    chunk_merged = pd.merge(business_RV, chunk, on='business_id', how='inner')
    # Show feedback on progress
    print(f"{chunk_merged.shape[0]} out of {size:,} related reviews")
    chunk_list.append(chunk_merged)

# After trimming down the review file, concatenate all relevant data back to one dataframe
df = pd.concat(chunk_list, ignore_index=True, join='outer', axis=0)
print(df.shape)
df.sample(3)
# Out:
# 55 out of 100,000 related reviews
# 73 out of 100,000 related reviews
# 70 out of 100,000 related reviews
# 134 out of 100,000 related reviews
# 181 out of 100,000 related reviews
# 215 out of 100,000 related reviews
# 267 out of 100,000 related reviews
# 54 out of 100,000 related reviews
# 31 out of 100,000 related reviews
# 34 out of 100,000 related reviews
# 54 out of 100,000 related reviews
# 82 out of 100,000 related reviews
# 95 out of 100,000 related reviews
# 162 out of 100,000 related reviews
# 105 out of 100,000 related reviews
# 75 out of 100,000 related reviews
# 81 out of 100,000 related reviews
# 113 out of 100,000 related reviews
# 145 out of 100,000 related reviews
# 212 out of 100,000 related reviews
# 227 out of 100,000 related reviews
# 61 out of 100,000 related reviews
# 54 out of 100,000 related reviews
# 63 out of 100,000 related reviews
# 64 out of 100,000 related reviews
# 107 out of 100,000 related reviews
# 118 out of 100,000 related reviews
# 123 out of 100,000 related reviews
# 106 out of 100,000 related reviews
# 76 out of 100,000 related reviews
# 111 out of 100,000 related reviews
# 102 out of 100,000 related reviews
# 142 out of 100,000 related reviews
# 255 out of 100,000 related reviews
# 194 out of 100,000 related reviews
# 34 out of 100,000 related reviews
# 31 out of 100,000 related reviews
# 32 out of 100,000 related reviews
# 59 out of 100,000 related reviews
# 105 out of 100,000 related reviews
# 106 out of 100,000 related reviews
# 96 out of 100,000 related reviews
# 47 out of 100,000 related reviews
# 54 out of 100,000 related reviews
# 38 out of 100,000 related reviews
# 76 out of 100,000 related reviews
# 99 out of 100,000 related reviews
# 164 out of 100,000 related reviews
# 115 out of 100,000 related reviews
# 53 out of 100,000 related reviews
# 43 out of 100,000 related reviews
# 37 out of 100,000 related reviews
# 75 out of 100,000 related reviews
# 101 out of 100,000 related reviews
# 161 out of 100,000 related reviews
# 134 out of 100,000 related reviews
# 68 out of 100,000 related reviews
# 68 out of 100,000 related reviews
# 103 out of 100,000 related reviews
# 203 out of 100,000 related reviews
# 241 out of 100,000 related reviews
# 262 out of 100,000 related reviews
# 255 out of 100,000 related reviews
# 87 out of 100,000 related reviews
# 101 out of 100,000 related reviews
# 107 out of 100,000 related reviews
# 142 out of 100,000 related reviews
# 193 out of 100,000 related reviews
# 223 out of 100,000 related reviews
# 220 out of 100,000 related reviews
# (7974, 15)
#                  business_id                  name              address  \
# 7964  EO0ZCmJv2ldtmI2E0DF59w            La Mesa RV  3255 E Irvington Rd
# 4972  SlkS9h_7QaFM2olSCPhBZw      Mount Comfort RV       5935 W 225th N
# 6138  z4DO84nKcdDNs9cvOlQ5Rw  Lazydays RV of Tampa  6130 Lazy Days Blvd
#
#             city state postal_code   latitude   longitude  stars  \
# 7964      Tucson    AZ       85714  32.163252 -110.922955    2.5
# 4972  Greenfield    IN       46140  39.817991  -85.911764    2.5
# 6138     Seffner    FL       33584  28.006551  -82.308538    2.5
#
#                                              attributes  \
# 7964             {'BusinessAcceptsCreditCards': 'True'}
# 4972  {'WiFi': 'u'free'', 'BusinessAcceptsCreditCard...
# 6138  {'BusinessAcceptsCreditCards': 'True', 'WiFi':...
#
#                                              categories  \
# 7964  Car Dealers, Auto Parts & Supplies, Automotive...
# 4972  RV Dealers, Hotels & Travel, Auto Parts & Supp...
# 6138  RV Dealers, RV Parks, Automotive, RV Repair, H...
#
#                      user_id  review_stars  \
# 7964  f9W-s412j8oPiweup9sSmw             1
# 4972  KSCLNFNcDiZm4q98LjvBBA             5
# 6138  ljYRQxsI0UY4i1MtkXu0-g             1
#
#                                                    text                 date
# 7964  We bought two rvs here, La Mesa Tucson. First ...  2019-06-13 21:16:19
# 4972  I've recommend Mount Comfort RV to a lot of my...  2015-06-23 16:19:52
# 6138  If anyone is planning to buy an RV please don'...  2015-10-01 12:01:09

# %% [markdown]
# ### Convert the new dataframe into a CSV file
#
# By doing so, the smaller dataset can be loaded and shared much more readily

# %%
df.to_csv("yelp_reviews_RV_categories.csv", index=False)
